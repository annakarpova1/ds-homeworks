# %%
# -*- coding: utf-8 -*-

# %%
import webbrowser

# %%
import urllib.request

# %%
chrome_path = 'C:/Program Files (x86)/Google/Chrome/Application/chrome.exe %s --incognito'
webbrowser.get(chrome_path).open('http://google.com')
# Out:
# True

# %%
url = "https://www.cian.ru/cat.php?deal_type=rent&engine_version=2&offer_type=offices&office_type%5B0%5D=1&office_type%5B1%5D=2&region=1"

# %%
webbrowser.get(chrome_path).open(url)
# Out:
# True

# %%
import http
import http.cookiejar

# %%
cj=http.cookiejar.CookieJar()

# %%
opener = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cj))
cj.clear()

# %%
url = "https://www.cian.ru/cat.php?deal_type=rent&engine_version=2&offer_type=offices&office_type%5B0%5D=1&office_type%5B1%5D=2&region=1"

# %%
r = opener.open(url)
data =r.read()

# %%
data_str = data.decode('utf-8')

# %%
import re
from bs4 import BeautifulSoup

# %%
urls = re.findall ("https://www.cian.ru/rent/commercial/\d*/", data_str)

# %%
urls_unique=(list(set(urls)))

# %%
urls_unique

# %%
# for item in object_ids_unique:
url=urls[0]
cj.clear()
r1 = opener.open(url)
data1 =(r1.read()).decode('utf-8')

# %%
data1_str
# Out:
# '\n\n<!DOCTYPE html>\n<html class="no-touch" >\n    <head>\n        \n        \n        \n    \n            <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\n            <meta name="google-site-verification" content="Eig23WXwvPZu3gp9EYVreR61rG4TX1bHQDEG0Di5ZSE"/>\n            <meta name="apple-mobile-web-app-title" content="ЦИАН">\n        \n    <meta name="apple-itunes-app" content="app-id=911804296, app-argument=https://www.cian.ru/rent/commercial/158217506/">\n    <link rel="alternate" href="android-app://ru.cian.main/cian/offer/rent/commercial/158217506/" />\n    <meta property="al:ios:url" content="cian://rent/commercial/158217506/" />\n<meta property="al:ios:app_store_id" content="911804296" />\n<meta property="al:ios:app_name" content="Cian" />\n<meta property="al:android:url" content="https://www.cian.ru/rent/commercial/158217506/" />\n<meta property="al:android:app_name" content="Cian" />\n<meta property="al:android:package" content="ru.cian.main" />\n<me
# ...

# %%
soup=BeautifulSoup(data1_str, "lxml")

# %%
soup.findAll("h1", { "class" : "object_descr_addr" })
# Out:
# [<h1 class="object_descr_addr" itemprop="alternateName">
#  <a href="https://www.cian.ru/snyat-torgovuyu-ploshad/" rel="nofollow" target="_blank">Москва</a>,
#
#
#          <a href="https://www.cian.ru/snyat-torgovuyu-ploshad-moskva-lefortovo-0475/" rel="nofollow" target="_blank">район Лефортово</a>,
#
#
#          <a href="https://www.cian.ru/snyat-torgovuyu-ploshad-moskva-krasnokazarmennaya-ulica-02184/" rel="nofollow" target="_blank">Красноказарменная ул.</a>,
#
#
#          <a href="/cat.php?deal_type=rent&amp;engine_version=2&amp;house%5B0%5D=1700924&amp;offer_type=offices&amp;office_type%5B0%5D=2" rel="nofollow" target="_blank">19</a>
#  </h1>]

# %%
(soup.findAll("div", { "class" : "object_descr_price" })[0].contents)[0].replace(u'\xa0', u' ').replace(u'\n', u'')
# Out:
# '      350 056 руб. в месяц  '

# %%
(soup.findAll("div", { "class" : "cf-object-descr-add" })[0].contents)[0]
# Out:
# <span>31 584 руб. за м² в год</span>

# %%
soup.findAll("dl", { "class" : "cf-comm-offer-detail__prop-list" })[0]
# Out:
# <dl class="cf-comm-offer-detail__prop-list">
# <dt class="cf-comm-offer-detail__prop-name">Обеспечительный платеж:</dt><dd class="cf-comm-offer-detail__prop-val">350 000 руб.</dd>
# <dt class="cf-comm-offer-detail__prop-name">Предоплата:</dt><dd class="cf-comm-offer-detail__prop-val">1 мес</dd>
# <dt class="cf-comm-offer-detail__prop-name">Тип аренды:</dt><dd class="cf-comm-offer-detail__prop-val">прямая</dd>
# <dt class="cf-comm-offer-detail__prop-name">Срок аренды:</dt><dd class="cf-comm-offer-detail__prop-val">длительный</dd>
# <dt class="cf-comm-offer-detail__prop-name">Минимальный срок аренды:</dt><dd class="cf-comm-offer-detail__prop-val">12 мес</dd>
# <dt class="cf-comm-offer-detail__prop-name">Арендные каникулы:</dt><dd class="cf-comm-offer-detail__prop-val">да</dd>
# </dl>

# %%
soup.findAll("div", { "class" : "object-descr__map-tabs__content js-object_descr__nearest" })[0].contents
# Out:
# ['\n', <map options="{
#                              center: [37.710171,55.753955],
#                              nearest: true,
#                              checkActive: true,
#                              nearestQuery: 'deal_type=rent&amp;offer_type=offices&amp;engine_version=2&amp;minprice=297547&amp;maxprice=402564&amp;office_type%5B0%5D=2&amp;skipids%5B0%5D=158217506'
#                          }"></map>, '\n', <div class="map_info_button_extend">
#  <a href="//www.cian.ru/map/?deal_type=1&amp;offices=yes&amp;center=55.753955%2C37.710171&amp;office_type[]=2&amp;ignore_cookie_region=1" rel="nofollow" target="_blank"><i></i>Посмотреть предложения рядом</a>
#  </div>, '\n']

# %%
result = soup.findAll("div", { "class" : "object_descr_text" })[0]

# %%
result.contents
# Out:
# ['\n                        \n                        ПРЯМАЯ АРЕНДА ОТ СОБСТВЕННИКА!',
#  <br/>,
#  'С риэлторами и агентствами недвижимости не работаем!',
#  <br/>,
#  <br/>,
#  'Рядом с метро Авиамоторная.',
#  <br/>,
#  'Огромный пешеходный трафик. Большой поток студентов.',
#  <br/>,
#  'Первый этаж жилого дома.',
#  <br/>,
#  'Два больших, витринных окна (ширина: 2,5 м; высота: 3,2 м).',
#  <br/>,
#  <br/>,
#  'ОСНОВНОЙ ЗАЛ:',
#  <br/>,
#  'Площадь - 80 кв\\м.',
#  <br/>,
#  'Высота потолков - 6 м.',
#  <br/>,
#  <br/>,
#  'ПОДСОБНЫЕ ПОМЕЩЕНИЯ:',
#  <br/>,
#  'Площадь - 53 кв\\м.',
#  <br/>,
#  'Высота потолков - 2,7 м.',
#  <br/>,
#  <br/>,
#  'Соседство: антикафе, копировальный центр, барбершоп.',
#  <br/>,
#  'Общая входная группа с барбершопом и копировальным центром.',
#  <br/>,
# ...
